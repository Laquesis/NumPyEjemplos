# %%
EJEMPLOS NUMPY

# %%
#IMPORTACIÓN LIBRERIA NUMPY
import numpy as np

# %% [markdown]
# Ejemplo 1
# Creo una matriz

# %%
a = np.array([0, 7, 8, 3 ],
             [3, 5, 10, 12],
             [7, 3, 9, 11])
